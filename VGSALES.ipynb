# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
# Create
new_row = {
    'Rank': 16601,
    'Name': 'New Game',
    'Platform': 'PC',
    'Year': 2025,
    'Genre': 'Action',
    'Publisher': 'New Publisher',
    'NA_Sales': 0.50,
    'EU_Sales': 0.30,
    'JP_Sales': 0.00,
    'Other_Sales': 0.20,
    'Global_Sales': 1.00
}

df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df
# Out:
#         Rank                      Name Platform    Year         Genre  \
# 0          1                Wii Sports      Wii  2006.0        Sports
# 1          2         Super Mario Bros.      NES  1985.0      Platform
# 2          3            Mario Kart Wii      Wii  2008.0        Racing
# 3          4         Wii Sports Resort      Wii  2009.0        Sports
# 4          5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ...      ...                       ...      ...     ...           ...
# 16596  16599                Know How 2       DS  2010.0        Puzzle
# 16597  16600          Spirits & Spells      GBA  2003.0      Platform
# 16598  16601                  New Game       PC  2025.0        Action
# 16599  16601                  New Game       PC  2025.0        Action
# 16600  16601                  New Game       PC  2025.0        Action
#
#            Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
#Read
action_games = df[df['Genre'] == 'Action']
print(action_games)
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 38        39                               Grand Theft Auto III      PS2
# ...      ...                                                ...      ...
# 16583  16586                                     Carmageddon 64      N64
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16598  16601                                           New Game       PC
# 16599  16601                                           New Game       PC
# 16600  16601                                           New Game       PC
#
#          Year   Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#update
df.loc[df['Name'] == 'New Game', 'Global_Sales'] = 1.5
df
# Out:
#         Rank                      Name Platform    Year         Genre  \
# 0          1                Wii Sports      Wii  2006.0        Sports
# 1          2         Super Mario Bros.      NES  1985.0      Platform
# 2          3            Mario Kart Wii      Wii  2008.0        Racing
# 3          4         Wii Sports Resort      Wii  2009.0        Sports
# 4          5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ...      ...                       ...      ...     ...           ...
# 16596  16599                Know How 2       DS  2010.0        Puzzle
# 16597  16600          Spirits & Spells      GBA  2003.0      Platform
# 16598  16601                  New Game       PC  2025.0        Action
# 16599  16601                  New Game       PC  2025.0        Action
# 16600  16601                  New Game       PC  2025.0        Action
#
#            Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
# delete 
df = df[df['Publisher'] != 'New Publisher']

# %%
top_games = df.sort_values(by='Global_Sales', ascending=False).head(10)

plt.figure(figsize=(12,6))
sns.barplot(data=top_games, x='Global_Sales', y='Name', palette='viridis')
plt.title('Top 10 Best Selling Games Globally')
plt.xlabel('Global Sales (Millions)')
plt.ylabel('Game Name')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7844\1911483966.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_games, x='Global_Sales', y='Name', palette='viridis')

# %%
sales_region = df.groupby('Genre')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum()

plt.figure(figsize=(10,6))
sns.heatmap(sales_region, annot=True, fmt=".1f", cmap='coolwarm')
plt.title('Sales by Region per Genre')
plt.xlabel('Region')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()

# %%
top_publishers = df['Publisher'].value_counts().head(10).index
df_top_publishers = df[df['Publisher'].isin(top_publishers)]

plt.figure(figsize=(14,6))
sns.boxplot(data=df_top_publishers, x='Publisher', y='Global_Sales')
plt.title('Sales Distribution by Publisher')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
games_per_year = df['Year'].value_counts().sort_index()

plt.figure(figsize=(12,6))
sns.lineplot(x=games_per_year.index, y=games_per_year.values)
plt.title('Number of Games Released Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Games')
plt.tight_layout()
plt.show()
